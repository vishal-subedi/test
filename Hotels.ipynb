# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
from sklearn.neural_network import MLPRegressor as mlp
from sklearn.linear_model import LinearRegression as lr
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor as dtr
from sklearn.ensemble import RandomForestRegressor as rfr
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.metrics import accuracy_score
ss = StandardScaler()
mas = MaxAbsScaler()

# %%
df = pd.read_csv('C:/Users/visha/Desktop/Datasets/hotels.csv', header = 0, index_col = None, sep = None, engine = 'python')

# %%
df.head(10)
# Out:
#   CityName  Population  CityRank  IsMetroCity  IsTouristDestination  \
# 0   Mumbai    12442373         0            1                     1
# 1   Mumbai    12442373         0            1                     1
# 2   Mumbai    12442373         0            1                     1
# 3   Mumbai    12442373         0            1                     1
# 4   Mumbai    12442373         0            1                     1
# 5   Mumbai    12442373         0            1                     1
# 6   Mumbai    12442373         0            1                     1
# 7   Mumbai    12442373         0            1                     1
# 8   Mumbai    12442373         0            1                     1
# 9   Mumbai    12442373         0            1                     1
#
#    IsWeekend  IsNewYearEve         Date               HotelName  RoomRent  \
# 0          1             0  Dec 18 2016          Vivanta by Taj     12375
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13232 entries, 0 to 13231
# Data columns (total 19 columns):
# CityName                13232 non-null object
# Population              13232 non-null int64
# CityRank                13232 non-null int64
# IsMetroCity             13232 non-null int64
# IsTouristDestination    13232 non-null int64
# IsWeekend               13232 non-null int64
# IsNewYearEve            13232 non-null int64
# Date                    13232 non-null object
# HotelName               13232 non-null object
# RoomRent                13232 non-null int64
# StarRating              13232 non-null float64
# Airport                 13232 non-null float64
# HotelAddress            13232 non-null object
# HotelPincode            13232 non-null int64
# HotelDescription        13224 non-null object
# FreeWifi                13232 non-null int64
# FreeBreakfast           13232 non-null int64
# HotelCapacity           13232 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['CityName', 'Population', 'CityRank', 'IsMetroCity',
#        'IsTouristDestination', 'IsWeekend', 'IsNewYearEve', 'Date',
#        'HotelName', 'RoomRent', 'StarRating', 'Airport', 'HotelAddress',
#        'HotelPincode', 'HotelDescription', 'FreeWifi', 'FreeBreakfast',
#        'HotelCapacity', 'HasSwimmingPool'],
#       dtype='object')

# %%
df_hotels = df.groupby('CityName')['HotelName'].nunique()

# %%
df_hotels
# Out:
# CityName
# Agra                 54
# Ahmedabad            53
# Amritsar             16
# Bangalore            87
# Bhubaneswar          15
# Chandigarh           46
# Chennai              51
# Darjeeling           17
# Delhi               272
# Gangtok              16
# Goa                  78
# Guwahati              6
# Haridwar              6
# Hyderabad            69
# Indore               20
# Jaipur               95
# Jaisalmer            33
# Jodhpur              27
# Kanpur                2
# Kochi                75
# Kolkata              90
# Lucknow              17
# Madurai              11
# Manali               36
# Mangalore            10
# Mumbai               62
# Munnar               41
# Mysore               20
# Nainital             18
# Ooty                 17
# Panchkula            29
# Pune                 75
# Puri                  7
# Rajkot               16
# Rishikesh            11
# Shimla               35
# Srinagar              5
# Surat                10
# ...

# %%
df[df['CityName'] == 'Mumbai']['HotelName'].value_counts()
# Out:
# The Gordon House Hotel                                24
# Grand Hometel Malad                                   16
# Hotel Landmark Annexe                                 16
# Hotel Sai Palace Grand Malad                          16
# Taj Lands End                                         16
# HOTEL A. K. INTERNATIONAL                             16
# OYO Rooms Vashi APMC Market                           16
# Fortune Select Exotica Navi Mumbai                    16
# Hotel Suncity Apollo                                  16
# FabHotel Golden Park Jogeshwari West                  16
# Grand Sarovar Premiere                                16
# Hotel Victoria                                        16
# Hotel Suba Palace                                     16
# Fabhotel Crawford Inn                                 16
# The E Hotel At Eskay Resorts                          16
# The Regenza by Tunga                                  16
# ...

# %%
dfh = df[df['CityName'] == 'Mumbai']
dfh1 = dfh[dfh['HotelName'] == 'Vivanta by Taj']

# %%
df['CityRank'].max(), df['CityRank'].min()
# Out:
# (44, 0)

# %%
dfh1[dfh1['Date'] == 'Jan 04 2017']
# Out:
#     CityName  Population  CityRank  IsMetroCity  IsTouristDestination  \
# 6     Mumbai    12442373         0            1                     1
# 550   Mumbai    12442373         0            1                     1
#
#      IsWeekend  IsNewYearEve         Date       HotelName  RoomRent  \
# 6            0             0  Jan 04 2017  Vivanta by Taj     11220
# 550          0             0  Jan 04 2017  Vivanta by Taj     11475
#
#      StarRating  Airport                                  HotelAddress  \
# 6           5.0     21.0  96 Cuffe Parade, Colaba, Mumbai, Maharashtra
# 550         5.0     21.0  96 Cuffe Parade, Colaba, Mumbai, Maharashtra
#
#      HotelPincode                              HotelDescription  FreeWifi  \
# 6          400011  Luxury hotel with spa, near Gateway of India         1
# 550        400005                         Luxury hotel with spa         1
#
#      FreeBreakfast  HotelCapacity  HasSwimmingPool
# 6                0            287                1
# ...

# %%
df2 = pd.crosstab([df3.HotelName, df3.IsWeekend, df3.IsNewYearEve, df3.Airport, df3.Date, df3.RoomRent], [df3.StarRating], margins = 1)
df2
# Out:
# StarRating                                                                                              2.0  \
# HotelName                                          IsWeekend IsNewYearEve Airport Date        RoomRent
# Bentleys Hotel Colaba                              0         0            20.0    Dec 21 2016 2700        0
#                                                                                   Dec 28 2016 2200        0
#                                                                                   Jan 04 2017 2700        0
#                                                    1         0            20.0    Dec 18 2016 2200        0
#                                                                                               2700        0
#                                                                                   Dec 24 2016 2700        0
#                                                                                               3000        0
# ...

# %%
df1 = df.groupby(['CityName' , 'HotelName', 'IsWeekend', 'IsNewYearEve', 'Date'])
df1['RoomRent'].value_counts()
# Out:
# CityName  HotelName                           IsWeekend  IsNewYearEve  Date         RoomRent
# Agra      ADB Rooms The Light House Agra      0          0             Dec 21 2016  2425        1
#                                                                        Dec 28 2016  2425        1
#                                                                        Jan 04 2017  2852        1
#                                               1          0             Dec 18 2016  2425        1
#                                                                        Dec 24 2016  2425        1
#                                                                        Dec 25 2016  2425        1
#                                                                        Jan 08 2017  2852        1
#                                                          1             Dec 31 2016  2425        1
#           Agra Regal Vista A sterling Resort  0          0             Dec 21 2016  3329        1
# ...

# %%
df3 = df[df['CityName'] == 'Mumbai']

# %%
hotel, count = np.unique(df.iloc[7224:7665,8].values, return_counts = 1)
np.asarray((hotel, count)).T
# Out:
# array([['ADB Rooms The Light House Agra', 8],
#        ['Agra Regal Vista A sterling Resort', 8],
#        ['Backpacker Panda Friends - Agra', 8],
#        ['Courtyard by Marriott Agra', 8],
#        ['Crystal Sarovar Premiere Agra', 8],
#        ['Double Tree by Hilton agra', 8],
#        ['G Hotel', 8],
#        ['Hotel Aditya Palace', 8],
#        ['Hotel Aicon Palace', 8],
#        ['Hotel Alleviate', 8],
#        ['Hotel Atulyaa Taj', 8],
#        ['Hotel Aura Mumtaz Mahal', 8],
#        ['Hotel Bhoomi Residency', 8],
#        ['Hotel Clarks Shiraz', 8],
#        ['Hotel Crystal Inn', 8],
#        ['Hotel Crystal Retreat', 8],
#        ['Hotel Dasaprakash', 8],
#        ['Hotel Deviram palace', 8],
#        ['Hotel Grace Agra', 8],
#        ['Hotel Idea Inn', 8],
#        ['Hotel Karan Vilas', 8],
#        ['Hotel Love Kush', 8],
#        ['Hotel Madhushrie', 8],
#        ['Hotel Royale Residency', 8],
#        ['Hotel Seven Hills Tower', 8],
#        ['Hotel Taj Heights', 8],
# ...

# %%
df_hotels.max(), df_hotels.min()
# Out:
# (272, 2)

# %%
X = df[['CityName', 'CityRank', 'IsMetroCity', 'IsTouristDestination', 'IsWeekend', 'IsNewYearEve', 'StarRating','Airport']]
y = df.RoomRent

# %%
X = 44 - X.iloc[:,1]

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.30, random_state = 1)

# %%
X_train1 = mas.fit_transform(X_train.reshape(-1,1))
X_test1 = mas.fit_transform(X_test.reshape(-1,1))

# %%
y_train.shape
# Out:
# (9262,)

# %%
clf = mlp(solver = 'sgd', activation = 'logistic', random_state = 1)

# %%
clf.fit(X_train.reshape(-1,1), y_train)
# Out:
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='sgd', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
pred = np.array(clf.predict(X_test.reshape(-1,1)))
act = np.array(y_test)
dev = 0
for i in range(len(act)):
    dev += abs(pred[i] - act[i])
    error =diff/len(act)
error
# Out:
# 3045.5455523316054

# %%
clf1 = rfr(n_estimators = 300, max_depth = 9, max_features = 0.67, random_state = 1)

# %%
clf1.fit(X_train1, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=9,
#            max_features=0.67, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
clf2 = lr(normalize = 1)

# %%
clf2.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=1)

# %%
clf
