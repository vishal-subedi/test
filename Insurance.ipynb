# %%
import numpy as np
import scipy as sp
import pandas as pd

# %%
df_train = pd.read_csv('C:/Users/visha/Downloads/Programs/train.csv', delimiter = ',', index_col = None, header = 0)
df_test = pd.read_csv('C:/Users/visha/Downloads/Programs/test.csv', delimiter = ',', index_col = None, header = 0)

# %%
df_train.head(10)
# Out:
#    id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0   7       0          2              2          5              1
# 1   9       0          1              1          7              0
# 2  13       0          5              4          9              1
# 3  16       0          0              1          2              0
# 4  17       0          0              2          0              1
# 5  19       0          5              1          4              0
# 6  20       0          2              1          3              1
# 7  22       0          5              1          4              0
# 8  26       0          5              1          3              1
# 9  28       1          1              1          2              0
#
#    ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin       ...        \
# 0              0              0              1              0       ...
# 1              0              0              0              1       ...
# ...

# %%
df_train.columns
# Out:
# Index(['id', 'target', 'ps_ind_01', 'ps_ind_02_cat', 'ps_ind_03',
#        'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_ind_06_bin', 'ps_ind_07_bin',
#        'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', 'ps_ind_11_bin',
#        'ps_ind_12_bin', 'ps_ind_13_bin', 'ps_ind_14', 'ps_ind_15',
#        'ps_ind_16_bin', 'ps_ind_17_bin', 'ps_ind_18_bin', 'ps_reg_01',
#        'ps_reg_02', 'ps_reg_03', 'ps_car_01_cat', 'ps_car_02_cat',
#        'ps_car_03_cat', 'ps_car_04_cat', 'ps_car_05_cat', 'ps_car_06_cat',
#        'ps_car_07_cat', 'ps_car_08_cat', 'ps_car_09_cat', 'ps_car_10_cat',
#        'ps_car_11_cat', 'ps_car_11', 'ps_car_12', 'ps_car_13', 'ps_car_14',
#        'ps_car_15', 'ps_calc_01', 'ps_calc_02', 'ps_calc_03', 'ps_calc_04',
#        'ps_calc_05', 'ps_calc_06', 'ps_calc_07', 'ps_calc_08', 'ps_calc_09',
#        'ps_calc_10', 'ps_calc_11', 'ps_calc_12', 'ps_calc_13', 'ps_calc_14',
#        'ps_calc_15_bin', 'ps_calc_16_bin', 'ps_calc_17_bin', 'ps_calc_18_bin',
# ...

# %%
df_train.shape
# Out:
# (595212, 59)

# %%
ind -> 18
reg -> 3
car -> 15
calc -> 20

# %%
df_train.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  595212.000000
# mean   7.438036e+05       0.036448       1.900378       1.358943
# std    4.293678e+05       0.187401       1.983789       0.664594
# min    7.000000e+00       0.000000       0.000000      -1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        4.423318       0.416794       0.405188       0.393742
# std         2.699902       0.493311       1.350642       0.488579
# min         0.000000      -1.000000      -1.000000       0.000000
# ...

# %%
df_train.apply(pd.Series.value_counts, axis = 1)
