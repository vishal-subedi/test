# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from textblob import TextBlob
import json
import time

# %%
#consumer key, consumer secret, access token, access secret.
ckey = 'vYvcVMYuG5E6zkCKE1Bv20OmP'
csecret = 'IeQdoaHIyshQ5RKXVgjeIG2bYRrn1M93McI6K4tm1WjB9fqaP6'
atoken = '147465780-2XJcemtPIhY5yvHJtEkztDP2qqxfYfBGX0ZpG61i'
asecret = 'oGA3F5njwq0AHvZRBjcBYZAMwJjS831N3bqU5NEy2zY9i'

# %%
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
api = tweepy.API(auth)
public_tweets = api.search('Narendra Modi')
file = open('sent.txt', 'w')
for i in public_tweets:
    print(i.text)
    file.write(i.encode('utf-8').text)
    file.write('\n')
    analysis = TextBlob(i.text)
    print(analysis.sentiment)
# Out:
# @goyalsanjeev @rsprasad @narendramodi @arunjaitley @sambitswaraj @Sanju_Verma_ @AmitShah What RS Prasad or Narendra… https://t.co/HEocl5PKHK
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-11e0fcd92144> in <module>()
#       6 for i in public_tweets:
#       7     print(i.text)
# ----> 8     file.write(i.encode('utf-8').text)
#       9     file.write('\n')
#      10     analysis = TextBlob(i.text)
#
# AttributeError: 'Status' object has no attribute 'encode'

# %%
#subjectivity - opinion vs factual

# %%
class listener(StreamListener):

    def on_data(self, data):

        tweet = data.split(',"text":"')[1].split('","source')[0]
        try:   
            output = open('twitterDB1.txt','a')
            output.write(tweet)
            output.write('\n')
            output.close()
            return True
        except (BaseException) as error:
            print("failed on data", error)
            time.sleep(5)

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["Elon"])

# %%
file = open('twitterDB1.txt', 'r')
for tweet in file:
    analysis = TextBlob(tweet)
    print(tweet, analysis.sentiment)
# Out:
# Elon Musk is a South African legend https:\/\/t.co\/nl6OUjIzkE","display_text_range":[0,35],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2804407228,"id_str":"2804407228","name":"Sibusiso Hlatshwayo","screen_name":"Sibusiso6305","location":"Durban, South Africa","url":null,"description":"Undergraduate Engineer\ud83d\udcda, Believes in God\ud83d\ude4f\ud83c\udfff, Dearly loved by his mom \ud83d\ude0a, sexy chubby nigga \ud83d\ude04","translator_type":"none","protected":false,"verified":false,"followers_count":244,"friends_count":873,"listed_count":0,"favourites_count":3788,"statuses_count":2683,"created_at":"Sat Oct 04 09:13:55 +0000 2014","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en"
# ...
